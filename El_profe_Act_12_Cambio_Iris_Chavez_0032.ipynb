# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280032-boop/Calcular-cambio-if-else/blob/main/El_profe_Act_12_Cambio_Iris_Chavez_0032.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Iris Chavez NL = 11 Fecha 26/mar/2026
# ### Calculando el cambio usando if else
# ### mirar el diagrama de flujo
# <img src="https://raw.githubusercontent.com/a25308051280032-boop/Calcular-cambio-if-else/refs/heads/main/calcular%20cambio.png">
#
# ## Las variables
# 1. CP = -->  Costo del producto
# 2. CD -->  Cantidad de dinero
# 3. Cambio
#
# ## Formulas
# $Cambio = CD - CP$
#
# ## Diagrama de flujo, lucichart
# <img src="https://raw.githubusercontent.com/a25308051280032-boop/Calcular-cambio-if-else/refs/heads/main/DF%20if%20else%20cambio%202.png" alt="DF" width="400">

# %%
# para cuando es verdadero (si)
# Calculando cambio usando if else
# datos de netrada CD , CP
# mostrar Cambio si es falso
# si es verdadero mostrar No alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
Cambio = CD - CP
if CP > CD:
    print("No alcanza")
else:
  cambio = CD - CP
  print("El cambio es: ", Cambio)
  print("Fin del programa")
  print("Programa realizado por Iris Chavez NL = 11")
# Out:
# Ingrese el costo del producto: 500
# Ingrese la cantidad de dinero: 400
# No alcanza

# %%
# para cuando es falso (no)
# Calculando cambio usando if else
# datos de netrada CD , CP
# mostrar Cambio si es falso
# si es verdadero mostrar No alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
Cambio = CD - CP
if CP > CD:
    print("No alcanza")
else:
    cambio = CD - CP
    print("El cambio es: ", Cambio)
    print("Fin del programa")
    print("Programa realizado por Iris Chavez NL = 11")
# Out:
# Ingrese el costo del producto: 250
# Ingrese la cantidad de dinero: 300
# El cambio es:  50.0
# Fin del programa
# Programa realizado por Iris Chavez NL = 11

# %% [markdown]
# ## Relacion entre codigo y diagrama de flujo
# <img src="https://raw.githubusercontent.com/a25308051280032-boop/Calcular-cambio-if-else/refs/heads/main/tldraw.png" alt="DF" width="800">
